# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# %%
def retrieveArticles(page, page_size):
    baseurl = f"https://www.cavalierdaily.com/section/quizzes?page={page}&per_page={page_size}"
    headers = {
        "User-Agent": "Mozilla/5.0"
    }

    response = requests.get(baseurl, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")
    links = []
    for a in soup.find_all("a", href = True):
        href = a["href"] 
        if "mini-crosswords" in href.lower():
            links.append(href)
    return links

# %%
print(retrieveArticles(1, 200))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print(retrieveArticles(1, 200))
#
# TypeError: retrieveArticles() takes 0 positional arguments but 2 were given
